# %%
# Data visualization
import numpy as np
import pandas as pd 

# Keras
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.optimizers import Adam
from keras.utils.np_utils import to_categorical
from keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
import keras_tuner as kt
import tensorflow as tf
import pydot as pyd
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

keras.utils.vis_utils.pydot = pyd

# Train-Test
from sklearn.model_selection import train_test_split
# Classification Report
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support

import pickle

import warnings
warnings.filterwarnings('ignore')

# %%
IMPORTANT_LMS = [
"NOSE",
"LEFT_SHOULDER",
"RIGHT_SHOULDER",
"LEFT_HIP",
"RIGHT_HIP",
"LEFT_KNEE",
"RIGHT_KNEE",
"LEFT_ANKLE",
"RIGHT_ANKLE",
]

# Generate all columns of the data frame

HEADERS = ["label"] # Label column

for lm in IMPORTANT_LMS:
    HEADERS += [f"{lm.lower()}_x", f"{lm.lower()}_y", f"{lm.lower()}_z", f"{lm.lower()}_v"]

# %%
def describe_dataset(dataset_path: str):
    '''
    Describe dataset
    '''

    data = pd.read_csv(dataset_path)
    print(f"Headers: {list(data.columns.values)}")
    print(f'Number of rows: {data.shape[0]} \nNumber of columns: {data.shape[1]}\n')
    print(f"Labels: \n{data['label'].value_counts()}\n")
    print(f"Missing values: {data.isnull().values.any()}\n")
    
    duplicate = data[data.duplicated()]
    print(f"Duplicate Rows : {len(duplicate.sum(axis=1))}")

    return data


# Remove duplicate rows (optional)
def remove_duplicate_rows(dataset_path: str):
    '''
    Remove duplicated data from the dataset then save it to another files
    '''
    
    df = pd.read_csv(dataset_path)
    df.drop_duplicates(keep="first", inplace=True)
    df.to_csv(f"cleaned_train.csv", sep=',', encoding='utf-8', index=False)


def round_up_metric_results(results) -> list:
    '''Round up metrics results such as precision score, recall score, ...'''
    return list(map(lambda el: round(el, 3), results))


df = describe_dataset("./train.csv")
# Out:
# Headers: ['label', 'nose_x', 'nose_y', 'nose_z', 'nose_v', 'left_shoulder_x', 'left_shoulder_y', 'left_shoulder_z', 'left_shoulder_v', 'right_shoulder_x', 'right_shoulder_y', 'right_shoulder_z', 'right_shoulder_v', 'left_hip_x', 'left_hip_y', 'left_hip_z', 'left_hip_v', 'right_hip_x', 'right_hip_y', 'right_hip_z', 'right_hip_v', 'left_knee_x', 'left_knee_y', 'left_knee_z', 'left_knee_v', 'right_knee_x', 'right_knee_y', 'right_knee_z', 'right_knee_v', 'left_ankle_x', 'left_ankle_y', 'left_ankle_z', 'left_ankle_v', 'right_ankle_x', 'right_ankle_y', 'right_ankle_z', 'right_ankle_v']
# Number of rows: 5235
# Number of columns: 37
#
# Labels:
# knees_forward_error    3931
# no_error               1304
# Name: label, dtype: int64
#
# Missing values: False
#
# Duplicate Rows : 0

# %%
# load dataset
df = pd.read_csv("./train.csv")

# Categorizing label
df.loc[df["label"] == "no_error", "label"] = 0
df.loc[df["label"] == "knees_forward_error", "label"] = 1

print(f'Number of rows: {df.shape[0]} \nNumber of columns: {df.shape[1]}\n')
print(f"Labels: \n{df['label'].value_counts()}\n")
# Out:
# Number of rows: 5235
# Number of columns: 37
#
# Labels:
# 1    3931
# 0    1304
# Name: label, dtype: int64

# %%
# Standard Scaling of features
# Dump input scaler
with open("./model/kf_input_scaler.pkl", "rb") as f2:
    sc = pickle.load(f2)

x = df.drop("label", axis = 1)
x = pd.DataFrame(sc.transform(x))

y = df["label"]

# # Converting prediction to categorical
y_cat = to_categorical(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x.values, y_cat, test_size=0.2, random_state=1234)

# %%
stop_early = EarlyStopping(monitor='loss', patience=3)

# Final Results
final_models = {}

# %%
def describe_model(model):
    '''
    Describe Model architecture
    '''
    print(f"Describe models architecture")
    for i, layer in enumerate(model.layers):
        number_of_units = layer.units if hasattr(layer, 'units') else 0

        if hasattr(layer, "activation"):
            print(f"Layer-{i + 1}: {number_of_units} units, func: ", layer.activation)
        else:
            print(f"Layer-{i + 1}: {number_of_units} units, func: None")
            

def get_best_model(tuner):
    '''
    Describe and return the best model found from keras tuner
    '''
    best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
    best_model = tuner.hypermodel.build(best_hps)

    describe_model(best_model)

    print("\nOther params:")
    ignore_params = ["tuner", "activation", "layer"]
    for param, value in best_hps.values.items():
        if not any(word in param for word in ignore_params):
            print(f"{param}: {value}")

    return best_model

# %%
def model_3l_builder(hp):
    model = Sequential()
    model.add(Dense(36, input_dim = 36, activation = "relu"))

    hp_activation = hp.Choice('activation', values=['relu', 'tanh'])
    hp_layer_1 = hp.Int('layer_1', min_value=32, max_value=512, step=32)
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.add(Dense(units=hp_layer_1, activation=hp_activation))
    model.add(Dense(2, activation = "softmax"))

    model.compile(optimizer=Adam(learning_rate=hp_learning_rate), loss="categorical_crossentropy", metrics = ["accuracy"])
    
    return model

# %%
tuner_3l = kt.Hyperband(
    model_3l_builder,
    objective='accuracy',
    max_epochs=10,
    directory='keras_tuner_dir',
    project_name='keras_tuner_demo'
)
tuner_3l.search(x_train, y_train, epochs=10, callbacks=[stop_early])
# Out:
# INFO:tensorflow:Reloading Tuner from keras_tuner_dir\keras_tuner_demo\tuner0.json
# INFO:tensorflow:Oracle triggered exit

# %%
model_3l = get_best_model(tuner_3l)
model_3l.fit(x_train, y_train, epochs=100, batch_size=10, validation_data=(x_test, y_test), callbacks=[stop_early])
# Out:
# Describe models architecture
# Layer-1: 36 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-2: 352 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-3: 2 units, func:  <function softmax at 0x0000020FBEE49430>
#
# Other params:
# learning_rate: 0.001
# Epoch 1/100
# 419/419 [==============================] - 2s 3ms/step - loss: 0.5293 - accuracy: 0.7701 - val_loss: 0.5124 - val_accuracy: 0.7813
# Epoch 2/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.4942 - accuracy: 0.7841 - val_loss: 0.5092 - val_accuracy: 0.7813
# Epoch 3/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.4736 - accuracy: 0.7973 - val_loss: 0.5249 - val_accuracy: 0.7755
# Epoch 4/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.4565 - accuracy: 0.8018 - val_loss: 0.4679 - val_accuracy: 0.7927
# Epoch 5/100
# 419/419 [==============================] - 1s 2ms/step - loss: 0.4386 - accuracy: 0.8114 - val_loss: 0.4788 - val_accuracy: 0.7794
# Epoch 6/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.4154 - accuracy: 0.8238 - val_loss: 0.4360 - val_accuracy: 0.8109
# Epoch 7/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.3911 - accuracy: 0.8340 - val_loss: 0.4421 - val_accuracy: 0.7994
# Epoch 8/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.3685 - accuracy: 0.8436 - val_loss: 0.4016 - val_accuracy: 0.8214
# Epoch 9/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.3542 - accuracy: 0.8481 - val_loss: 0.3932 - val_accuracy: 0.8233
# Epoch 10/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.3296 - accuracy: 0.8603 - val_loss: 0.3983 - val_accuracy: 0.8309
# Epoch 11/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.3116 - accuracy: 0.8701 - val_loss: 0.3888 - val_accuracy: 0.8367
# Epoch 12/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.2960 - accuracy: 0.8801 - val_loss: 0.3577 - val_accuracy: 0.8481
# Epoch 13/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.2744 - accuracy: 0.8894 - val_loss: 0.3819 - val_accuracy: 0.8252
# Epoch 14/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.2565 - accuracy: 0.8966 - val_loss: 0.3551 - val_accuracy: 0.8443
# Epoch 15/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.2444 - accuracy: 0.9019 - val_loss: 0.3573 - val_accuracy: 0.8577
# Epoch 16/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.2292 - accuracy: 0.9062 - val_loss: 0.3244 - val_accuracy: 0.8739
# Epoch 17/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.2145 - accuracy: 0.9202 - val_loss: 0.3379 - val_accuracy: 0.8653
# Epoch 18/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.2009 - accuracy: 0.9183 - val_loss: 0.3161 - val_accuracy: 0.8797
# Epoch 19/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.2025 - accuracy: 0.9219 - val_loss: 0.3448 - val_accuracy: 0.8663
# Epoch 20/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.1805 - accuracy: 0.9284 - val_loss: 0.3337 - val_accuracy: 0.8806
# Epoch 21/100
# 419/419 [==============================] - 1s 4ms/step - loss: 0.1650 - accuracy: 0.9370 - val_loss: 0.3210 - val_accuracy: 0.8787
# Epoch 22/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.1645 - accuracy: 0.9370 - val_loss: 0.3065 - val_accuracy: 0.8806
# Epoch 23/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.1492 - accuracy: 0.9448 - val_loss: 0.3236 - val_accuracy: 0.8873
# Epoch 24/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.1388 - accuracy: 0.9472 - val_loss: 0.3335 - val_accuracy: 0.8787
# Epoch 25/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.1345 - accuracy: 0.9499 - val_loss: 0.3061 - val_accuracy: 0.8835
# Epoch 26/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.1207 - accuracy: 0.9606 - val_loss: 0.3201 - val_accuracy: 0.8816
# Epoch 27/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1246 - accuracy: 0.9537 - val_loss: 0.3162 - val_accuracy: 0.8968
# Epoch 28/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1090 - accuracy: 0.9604 - val_loss: 0.3279 - val_accuracy: 0.8787
# Epoch 29/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1106 - accuracy: 0.9565 - val_loss: 0.3279 - val_accuracy: 0.8911
# Epoch 30/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.1057 - accuracy: 0.9594 - val_loss: 0.3479 - val_accuracy: 0.8816
# Epoch 31/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0945 - accuracy: 0.9673 - val_loss: 0.3181 - val_accuracy: 0.8911
# Epoch 32/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.0907 - accuracy: 0.9678 - val_loss: 0.3270 - val_accuracy: 0.8863
# Epoch 33/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.0848 - accuracy: 0.9725 - val_loss: 0.3298 - val_accuracy: 0.8949
# Epoch 34/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0896 - accuracy: 0.9690 - val_loss: 0.3073 - val_accuracy: 0.8911
# Epoch 35/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.0776 - accuracy: 0.9745 - val_loss: 0.3564 - val_accuracy: 0.8835
# Epoch 36/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.0650 - accuracy: 0.9795 - val_loss: 0.3421 - val_accuracy: 0.8940
# Epoch 37/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.0780 - accuracy: 0.9735 - val_loss: 0.3069 - val_accuracy: 0.9035
# Epoch 38/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.0691 - accuracy: 0.9766 - val_loss: 0.4730 - val_accuracy: 0.8682
# Epoch 39/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.0931 - accuracy: 0.9654 - val_loss: 0.3399 - val_accuracy: 0.8968

# %%
final_models["3_layers"] = model_3l

# %%
def model_5l_builder(hp):
    model = Sequential()
    model.add(Dense(36, input_dim = 36, activation = "relu"))

    hp_activation = hp.Choice('activation', values=['relu', 'tanh'])
    hp_layer_1 = hp.Int('layer_1', min_value=32, max_value=512, step=32)
    hp_layer_2 = hp.Int('layer_2', min_value=32, max_value=512, step=32)
    hp_layer_3 = hp.Int('layer_3', min_value=32, max_value=512, step=32)
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.add(Dense(units=hp_layer_1, activation=hp_activation))
    model.add(Dense(units=hp_layer_2, activation=hp_activation))
    model.add(Dense(units=hp_layer_3, activation=hp_activation))
    model.add(Dense(2, activation = "softmax"))

    model.compile(optimizer=Adam(learning_rate=hp_learning_rate), loss="categorical_crossentropy", metrics = ["accuracy"])
    
    return model

# %%
import keras
tuner_5l = kt.Hyperband(
    model_5l_builder,
    objective='accuracy',
    max_epochs=10,
    directory='keras_tuner_dir',
    project_name='keras_tuner_demo_1'
)

tuner_5l.search(
    x_train, 
    y_train, 
    epochs=10, 
    callbacks=[keras.callbacks.EarlyStopping(patience=5)]
)
# Out:
# INFO:tensorflow:Reloading Tuner from keras_tuner_dir\keras_tuner_demo_1\tuner0.json
# INFO:tensorflow:Oracle triggered exit

# %%
model_5l = get_best_model(tuner_5l)
model_5l.fit(x_train, y_train, epochs=100, batch_size=10, validation_data=(x_test, y_test), callbacks=[stop_early])
# Out:
# Describe models architecture
# Layer-1: 36 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-2: 320 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-3: 384 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-4: 224 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-5: 2 units, func:  <function softmax at 0x0000020FBEE49430>
#
# Other params:
# learning_rate: 0.001
# Epoch 1/100
# 419/419 [==============================] - 3s 5ms/step - loss: 0.5403 - accuracy: 0.7686 - val_loss: 0.5147 - val_accuracy: 0.7689
# Epoch 2/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.4971 - accuracy: 0.7820 - val_loss: 0.5044 - val_accuracy: 0.7736
# Epoch 3/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.4641 - accuracy: 0.7992 - val_loss: 0.4630 - val_accuracy: 0.7985
# Epoch 4/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.4334 - accuracy: 0.8135 - val_loss: 0.4539 - val_accuracy: 0.8013
# Epoch 5/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.3927 - accuracy: 0.8259 - val_loss: 0.4689 - val_accuracy: 0.8004
# Epoch 6/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.3619 - accuracy: 0.8474 - val_loss: 0.3879 - val_accuracy: 0.8195
# Epoch 7/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.3237 - accuracy: 0.8608 - val_loss: 0.3989 - val_accuracy: 0.8357
# Epoch 8/100
# 419/419 [==============================] - 2s 6ms/step - loss: 0.3057 - accuracy: 0.8713 - val_loss: 0.3681 - val_accuracy: 0.8472
# Epoch 9/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.2651 - accuracy: 0.8887 - val_loss: 0.3322 - val_accuracy: 0.8577
# Epoch 10/100
# 419/419 [==============================] - 2s 6ms/step - loss: 0.2428 - accuracy: 0.9009 - val_loss: 0.3031 - val_accuracy: 0.8797
# Epoch 11/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.2026 - accuracy: 0.9143 - val_loss: 0.2737 - val_accuracy: 0.8863
# Epoch 12/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1817 - accuracy: 0.9262 - val_loss: 0.2812 - val_accuracy: 0.8835
# Epoch 13/100
# 419/419 [==============================] - 2s 6ms/step - loss: 0.1705 - accuracy: 0.9346 - val_loss: 0.3725 - val_accuracy: 0.8663
# Epoch 14/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.1498 - accuracy: 0.9401 - val_loss: 0.3526 - val_accuracy: 0.8758
# Epoch 15/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.1293 - accuracy: 0.9482 - val_loss: 0.3205 - val_accuracy: 0.8883
# Epoch 16/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1359 - accuracy: 0.9472 - val_loss: 0.2792 - val_accuracy: 0.8997
# Epoch 17/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1108 - accuracy: 0.9575 - val_loss: 0.3130 - val_accuracy: 0.8978
# Epoch 18/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1163 - accuracy: 0.9530 - val_loss: 0.2688 - val_accuracy: 0.9074
# Epoch 19/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0955 - accuracy: 0.9680 - val_loss: 0.2572 - val_accuracy: 0.9045
# Epoch 20/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0940 - accuracy: 0.9642 - val_loss: 0.2805 - val_accuracy: 0.9016
# Epoch 21/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0840 - accuracy: 0.9699 - val_loss: 0.3058 - val_accuracy: 0.9074
# Epoch 22/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.0834 - accuracy: 0.9687 - val_loss: 0.3149 - val_accuracy: 0.9083
# Epoch 23/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0770 - accuracy: 0.9730 - val_loss: 0.2999 - val_accuracy: 0.9169
# Epoch 24/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0709 - accuracy: 0.9742 - val_loss: 0.2574 - val_accuracy: 0.9169
# Epoch 25/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0684 - accuracy: 0.9740 - val_loss: 0.3634 - val_accuracy: 0.9074
# Epoch 26/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0658 - accuracy: 0.9766 - val_loss: 0.2378 - val_accuracy: 0.9284
# Epoch 27/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0607 - accuracy: 0.9787 - val_loss: 0.2964 - val_accuracy: 0.9150
# Epoch 28/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0751 - accuracy: 0.9709 - val_loss: 0.2583 - val_accuracy: 0.9226
# Epoch 29/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0675 - accuracy: 0.9776 - val_loss: 0.2803 - val_accuracy: 0.9322
# Epoch 30/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.0423 - accuracy: 0.9871 - val_loss: 0.3556 - val_accuracy: 0.9150
# Epoch 31/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0607 - accuracy: 0.9799 - val_loss: 0.2884 - val_accuracy: 0.9207
# Epoch 32/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.0530 - accuracy: 0.9811 - val_loss: 0.3249 - val_accuracy: 0.9131
# Epoch 33/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0531 - accuracy: 0.9814 - val_loss: 0.3006 - val_accuracy: 0.9121

# %%
final_models["5_layers"] = model_5l

# %%
def model_7lD_builder(hp):
    model = Sequential()
    model.add(Dense(36, input_dim = 36, activation = "relu"))

    hp_activation = hp.Choice('activation', values=['relu', 'tanh'])
    hp_layer_1 = hp.Int('layer_1', min_value=32, max_value=512, step=32)
    hp_layer_2 = hp.Int('layer_2', min_value=32, max_value=512, step=32)
    hp_layer_3 = hp.Int('layer_3', min_value=32, max_value=512, step=32)
    hp_dropout_1 = hp.Float('dropout_1', min_value=0.1, max_value=0.5, step=0.1)
    hp_dropout_2 = hp.Float('dropout_2', min_value=0.1, max_value=0.5, step=0.1)
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.add(Dense(units=hp_layer_1, activation=hp_activation))
    model.add(Dropout(rate=hp_dropout_1))
    model.add(Dense(units=hp_layer_2, activation=hp_activation))
    model.add(Dropout(rate=hp_dropout_2))
    model.add(Dense(units=hp_layer_3, activation=hp_activation))
    model.add(Dense(2, activation = "softmax"))

    model.compile(optimizer=Adam(learning_rate=hp_learning_rate), loss="categorical_crossentropy", metrics = ["accuracy"])
    
    return model

# %%
def get_early_stopping_callback():
    return keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=3
    )

tuner_7lD = kt.Hyperband(
    model_7lD_builder,
    objective='accuracy',
    max_epochs=10,
    directory='keras_tuner_dir',
    project_name='keras_tuner_demo_4'
)
tuner_7lD.search(x_train, y_train, epochs=10, callbacks=[get_early_stopping_callback()])
# Out:
# INFO:tensorflow:Reloading Tuner from keras_tuner_dir\keras_tuner_demo_4\tuner0.json
# INFO:tensorflow:Oracle triggered exit

# %%
model_7lD = get_best_model(tuner_7lD)
model_7lD.fit(x_train, y_train, epochs=100, batch_size=10, validation_data=(x_test, y_test), callbacks=[stop_early])
# Out:
# Describe models architecture
# Layer-1: 36 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-2: 64 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-3: 0 units, func: None
# Layer-4: 448 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-5: 0 units, func: None
# Layer-6: 160 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-7: 2 units, func:  <function softmax at 0x0000020FBEE49430>
#
# Other params:
# dropout_1: 0.1
# dropout_2: 0.2
# learning_rate: 0.001
# Epoch 1/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.5339 - accuracy: 0.7710 - val_loss: 0.5271 - val_accuracy: 0.7622
# Epoch 2/100
# 419/419 [==============================] - 1s 4ms/step - loss: 0.4946 - accuracy: 0.7820 - val_loss: 0.5010 - val_accuracy: 0.7698
# Epoch 3/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.4779 - accuracy: 0.7925 - val_loss: 0.4938 - val_accuracy: 0.7775
# Epoch 4/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.4569 - accuracy: 0.8044 - val_loss: 0.4885 - val_accuracy: 0.7841
# Epoch 5/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.4340 - accuracy: 0.8126 - val_loss: 0.4409 - val_accuracy: 0.8032
# Epoch 6/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.4120 - accuracy: 0.8250 - val_loss: 0.4450 - val_accuracy: 0.7956
# Epoch 7/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.3975 - accuracy: 0.8305 - val_loss: 0.4277 - val_accuracy: 0.7956
# Epoch 8/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.3760 - accuracy: 0.8386 - val_loss: 0.4151 - val_accuracy: 0.8185
# Epoch 9/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.3641 - accuracy: 0.8431 - val_loss: 0.4085 - val_accuracy: 0.8109
# Epoch 10/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.3436 - accuracy: 0.8517 - val_loss: 0.3825 - val_accuracy: 0.8243
# Epoch 11/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.3307 - accuracy: 0.8603 - val_loss: 0.3851 - val_accuracy: 0.8329
# Epoch 12/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.3148 - accuracy: 0.8639 - val_loss: 0.3632 - val_accuracy: 0.8491
# Epoch 13/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.2948 - accuracy: 0.8756 - val_loss: 0.3774 - val_accuracy: 0.8386
# Epoch 14/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.2821 - accuracy: 0.8823 - val_loss: 0.3788 - val_accuracy: 0.8348
# Epoch 15/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.2757 - accuracy: 0.8830 - val_loss: 0.3420 - val_accuracy: 0.8577
# Epoch 16/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.2651 - accuracy: 0.8844 - val_loss: 0.3519 - val_accuracy: 0.8462
# Epoch 17/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.2447 - accuracy: 0.8968 - val_loss: 0.3830 - val_accuracy: 0.8596
# Epoch 18/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.2469 - accuracy: 0.8918 - val_loss: 0.3584 - val_accuracy: 0.8453
# Epoch 19/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.2319 - accuracy: 0.9043 - val_loss: 0.3318 - val_accuracy: 0.8625
# Epoch 20/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.2295 - accuracy: 0.9028 - val_loss: 0.3342 - val_accuracy: 0.8625
# Epoch 21/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.2134 - accuracy: 0.9076 - val_loss: 0.3874 - val_accuracy: 0.8606
# Epoch 22/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.2244 - accuracy: 0.9093 - val_loss: 0.3465 - val_accuracy: 0.8625
# Epoch 23/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1986 - accuracy: 0.9128 - val_loss: 0.3793 - val_accuracy: 0.8672
# Epoch 24/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.2051 - accuracy: 0.9181 - val_loss: 0.2860 - val_accuracy: 0.8863
# Epoch 25/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.1937 - accuracy: 0.9162 - val_loss: 0.3568 - val_accuracy: 0.8663
# Epoch 26/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1846 - accuracy: 0.9267 - val_loss: 0.3092 - val_accuracy: 0.8978
# Epoch 27/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.1801 - accuracy: 0.9277 - val_loss: 0.3211 - val_accuracy: 0.8911
# Epoch 28/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.1765 - accuracy: 0.9250 - val_loss: 0.3448 - val_accuracy: 0.8883
# Epoch 29/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.1660 - accuracy: 0.9355 - val_loss: 0.3387 - val_accuracy: 0.8758
# Epoch 30/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.1666 - accuracy: 0.9355 - val_loss: 0.3185 - val_accuracy: 0.8997
# Epoch 31/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.1649 - accuracy: 0.9324 - val_loss: 0.3083 - val_accuracy: 0.8911
# Epoch 32/100
# 419/419 [==============================] - 3s 7ms/step - loss: 0.1545 - accuracy: 0.9377 - val_loss: 0.3476 - val_accuracy: 0.8854
# Epoch 33/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.1497 - accuracy: 0.9434 - val_loss: 0.3497 - val_accuracy: 0.8921
# Epoch 34/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1532 - accuracy: 0.9434 - val_loss: 0.3323 - val_accuracy: 0.8892
# Epoch 35/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1441 - accuracy: 0.9425 - val_loss: 0.3168 - val_accuracy: 0.8892
# Epoch 36/100
# 419/419 [==============================] - 1s 4ms/step - loss: 0.1426 - accuracy: 0.9427 - val_loss: 0.3086 - val_accuracy: 0.8902
# Epoch 37/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1548 - accuracy: 0.9377 - val_loss: 0.2981 - val_accuracy: 0.8959
# Epoch 38/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.1212 - accuracy: 0.9503 - val_loss: 0.3565 - val_accuracy: 0.8930
# Epoch 39/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1291 - accuracy: 0.9489 - val_loss: 0.3323 - val_accuracy: 0.9016
# Epoch 40/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1305 - accuracy: 0.9491 - val_loss: 0.3190 - val_accuracy: 0.8997
# Epoch 41/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1173 - accuracy: 0.9565 - val_loss: 0.3165 - val_accuracy: 0.8854
# Epoch 42/100
# 419/419 [==============================] - 1s 4ms/step - loss: 0.1273 - accuracy: 0.9477 - val_loss: 0.3133 - val_accuracy: 0.9093
# Epoch 43/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1118 - accuracy: 0.9585 - val_loss: 0.3293 - val_accuracy: 0.9083
# Epoch 44/100
# 419/419 [==============================] - 1s 4ms/step - loss: 0.1187 - accuracy: 0.9527 - val_loss: 0.3083 - val_accuracy: 0.8997
# Epoch 45/100
# 419/419 [==============================] - 1s 4ms/step - loss: 0.1136 - accuracy: 0.9549 - val_loss: 0.3421 - val_accuracy: 0.8911
# Epoch 46/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.1047 - accuracy: 0.9616 - val_loss: 0.3908 - val_accuracy: 0.9007
# Epoch 47/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1122 - accuracy: 0.9561 - val_loss: 0.3409 - val_accuracy: 0.8978
# Epoch 48/100
# 419/419 [==============================] - 1s 3ms/step - loss: 0.1173 - accuracy: 0.9553 - val_loss: 0.3687 - val_accuracy: 0.8835
# Epoch 49/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1194 - accuracy: 0.9537 - val_loss: 0.3644 - val_accuracy: 0.8883

# %%
final_models["7_layers_with_dropout"] = model_7lD

# %%
def model_7l_builder(hp):
    model = Sequential()
    model.add(Dense(36, input_dim = 36, activation = "relu"))

    hp_activation = hp.Choice('activation', values=['relu', 'tanh'])
    hp_layer_1 = hp.Int('layer_1', min_value=32, max_value=512, step=32)
    hp_layer_2 = hp.Int('layer_2', min_value=32, max_value=512, step=32)
    hp_layer_3 = hp.Int('layer_3', min_value=32, max_value=512, step=32)
    hp_layer_4 = hp.Int('layer_4', min_value=32, max_value=512, step=32)
    hp_layer_5 = hp.Int('layer_5', min_value=32, max_value=512, step=32)
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.add(Dense(units=hp_layer_1, activation=hp_activation))
    model.add(Dense(units=hp_layer_2, activation=hp_activation))
    model.add(Dense(units=hp_layer_3, activation=hp_activation))
    model.add(Dense(units=hp_layer_4, activation=hp_activation))
    model.add(Dense(units=hp_layer_5, activation=hp_activation))
    model.add(Dense(2, activation = "softmax"))

    model.compile(optimizer=Adam(learning_rate=hp_learning_rate), loss="categorical_crossentropy", metrics = ["accuracy"])
    return model

# %%
tuner_7l = kt.Hyperband(
    model_7l_builder,
    objective='accuracy',
    max_epochs=10,
    directory='keras_tuner_dir',
    project_name='keras_tuner_demo_5'
)
tuner_7l.search(x_train, y_train, epochs=10, callbacks=[keras.callbacks.EarlyStopping(patience=5)])
# Out:
# INFO:tensorflow:Reloading Tuner from keras_tuner_dir\keras_tuner_demo_5\tuner0.json
# INFO:tensorflow:Oracle triggered exit

# %%
model_7l = get_best_model(tuner_7l)
model_7l.fit(x_train, y_train, epochs=100, batch_size=10, validation_data=(x_test, y_test), callbacks=[stop_early])
# Out:
# Describe models architecture
# Layer-1: 36 units, func:  <function relu at 0x000001F290D48280>
# Layer-2: 416 units, func:  <function relu at 0x000001F290D48280>
# Layer-3: 192 units, func:  <function relu at 0x000001F290D48280>
# Layer-4: 64 units, func:  <function relu at 0x000001F290D48280>
# Layer-5: 384 units, func:  <function relu at 0x000001F290D48280>
# Layer-6: 256 units, func:  <function relu at 0x000001F290D48280>
# Layer-7: 2 units, func:  <function softmax at 0x000001F290D3F820>
#
# Other params:
# learning_rate: 0.001
# Epoch 1/100
# 419/419 [==============================] - 3s 5ms/step - loss: 0.5333 - accuracy: 0.7686 - val_loss: 0.5107 - val_accuracy: 0.7746
# Epoch 2/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.4982 - accuracy: 0.7846 - val_loss: 0.4975 - val_accuracy: 0.7708
# Epoch 3/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.4704 - accuracy: 0.7970 - val_loss: 0.4967 - val_accuracy: 0.7736
# Epoch 4/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.4423 - accuracy: 0.8126 - val_loss: 0.4626 - val_accuracy: 0.7927
# Epoch 5/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.4149 - accuracy: 0.8233 - val_loss: 0.4230 - val_accuracy: 0.8214
# Epoch 6/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.3775 - accuracy: 0.8431 - val_loss: 0.4073 - val_accuracy: 0.8252
# Epoch 7/100
# 419/419 [==============================] - 2s 6ms/step - loss: 0.3587 - accuracy: 0.8520 - val_loss: 0.3878 - val_accuracy: 0.8309
# Epoch 8/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.3318 - accuracy: 0.8653 - val_loss: 0.3861 - val_accuracy: 0.8453
# Epoch 9/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.3048 - accuracy: 0.8746 - val_loss: 0.4110 - val_accuracy: 0.8290
# Epoch 10/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.2777 - accuracy: 0.8854 - val_loss: 0.3885 - val_accuracy: 0.8415
# Epoch 11/100
# 419/419 [==============================] - 2s 6ms/step - loss: 0.2620 - accuracy: 0.8937 - val_loss: 0.3744 - val_accuracy: 0.8567
# Epoch 12/100
# 419/419 [==============================] - 3s 6ms/step - loss: 0.2389 - accuracy: 0.9045 - val_loss: 0.3644 - val_accuracy: 0.8453
# Epoch 13/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.2092 - accuracy: 0.9191 - val_loss: 0.3053 - val_accuracy: 0.8730
# Epoch 14/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.2000 - accuracy: 0.9183 - val_loss: 0.2978 - val_accuracy: 0.8892
# Epoch 15/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1825 - accuracy: 0.9253 - val_loss: 0.3033 - val_accuracy: 0.8883
# Epoch 16/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.1688 - accuracy: 0.9329 - val_loss: 0.3927 - val_accuracy: 0.8768
# Epoch 17/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1538 - accuracy: 0.9401 - val_loss: 0.3229 - val_accuracy: 0.8730
# Epoch 18/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1491 - accuracy: 0.9444 - val_loss: 0.3326 - val_accuracy: 0.8768
# Epoch 19/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1514 - accuracy: 0.9444 - val_loss: 0.3035 - val_accuracy: 0.8873
# Epoch 20/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1389 - accuracy: 0.9472 - val_loss: 0.3140 - val_accuracy: 0.8930
# Epoch 21/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1147 - accuracy: 0.9563 - val_loss: 0.3158 - val_accuracy: 0.9026
# Epoch 22/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1190 - accuracy: 0.9542 - val_loss: 0.4130 - val_accuracy: 0.8892
# Epoch 23/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1085 - accuracy: 0.9606 - val_loss: 0.3427 - val_accuracy: 0.8968
# Epoch 24/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.1091 - accuracy: 0.9580 - val_loss: 0.3778 - val_accuracy: 0.8787
# Epoch 25/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.1047 - accuracy: 0.9618 - val_loss: 0.2566 - val_accuracy: 0.9131
# Epoch 26/100
# 419/419 [==============================] - 2s 5ms/step - loss: 0.1022 - accuracy: 0.9620 - val_loss: 0.3651 - val_accuracy: 0.9140
# Epoch 27/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0971 - accuracy: 0.9670 - val_loss: 0.3568 - val_accuracy: 0.8997
# Epoch 28/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0873 - accuracy: 0.9668 - val_loss: 0.3395 - val_accuracy: 0.9102
# Epoch 29/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0728 - accuracy: 0.9733 - val_loss: 0.4258 - val_accuracy: 0.9054
# Epoch 30/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0905 - accuracy: 0.9687 - val_loss: 0.2978 - val_accuracy: 0.8911
# Epoch 31/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0805 - accuracy: 0.9745 - val_loss: 0.3413 - val_accuracy: 0.8978
# Epoch 32/100
# 419/419 [==============================] - 2s 4ms/step - loss: 0.0725 - accuracy: 0.9747 - val_loss: 0.3516 - val_accuracy: 0.9169
# Epoch 33/100
# 161/419 [==========>...................] - ETA: 0s - loss: 0.0366 - accuracy: 0.9870

# %%
def visualize_model(model):
      return SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %%
final_models["7_layers"] = model_7l

# %%
visualize_model(final_models["7_layers"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pydot.py in create(self, prog, format)
#    1872         try:
# -> 1873             p = subprocess.Popen(
#    1874                 cmdline,
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# ~\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1419             try:
# -> 1420                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                                          # no special security
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12612\400277623.py in <module>
# ----> 1 visualize_model(final_models["7_layers"])
#
# ~\AppData\Local\Temp\ipykernel_12612\540613088.py in visualize_model(model)
#       1 def visualize_model(model):
# ----> 2       return SVG(model_to_dot(model).create(prog='dot', format='svg'))
#
# ~\anaconda3\lib\site-packages\pydot.py in create(self, prog, format)
#    1878                 stderr=subprocess.PIPE, stdout=subprocess.PIPE)
#    1879         except OSError as e:
# -> 1880             if e.errno == os.errno.ENOENT:
#    1881                 raise Exception(
#    1882                     '"{prog}" not found in path.'.format(
#
# AttributeError: module 'os' has no attribute 'errno'

# %%
for name, model in final_models.items():
    print(f"{name}: ", end="")
    describe_model(model)
    print()
# Out:
# 3_layers: Describe models architecture
# Layer-1: 36 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-2: 352 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-3: 2 units, func:  <function softmax at 0x0000020FBEE49430>
#
# 5_layers: Describe models architecture
# Layer-1: 36 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-2: 320 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-3: 384 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-4: 224 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-5: 2 units, func:  <function softmax at 0x0000020FBEE49430>
#
# 7_layers_with_dropout: Describe models architecture
# Layer-1: 36 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-2: 64 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-3: 0 units, func: None
# Layer-4: 448 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-5: 0 units, func: None
# Layer-6: 160 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-7: 2 units, func:  <function softmax at 0x0000020FBEE49430>
#
# 7_layers: Describe models architecture
# Layer-1: 36 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-2: 416 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-3: 192 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-4: 64 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-5: 384 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-6: 256 units, func:  <function relu at 0x0000020FBEE49E50>
# Layer-7: 2 units, func:  <function softmax at 0x0000020FBEE49430>

# %%
train_set_results = []

for name, model in final_models.items():
    # Evaluate model
    predict_x = model.predict(x_test, verbose=False) 
    y_pred_class = np.argmax(predict_x, axis=1)
    y_test_class = np.argmax(y_test, axis=1)

    cm = confusion_matrix(y_test_class, y_pred_class, labels=[0, 1, 2])
    (p_score, r_score, f_score, _) = precision_recall_fscore_support(y_test_class, y_pred_class, labels=[0, 1, 2])
    
    train_set_results.append(( name, round_up_metric_results(p_score), round_up_metric_results(r_score), round_up_metric_results(f_score), cm ))

train_set_results.sort(key=lambda k: sum(k[3]), reverse=True)
pd.DataFrame(train_set_results, columns=["Model", "Precision Score", "Recall Score", "F1 score", "Confusion Matrix"])
# Out:
#                    Model      Precision Score         Recall Score  \
# 0               5_layers  [0.822, 0.943, 0.0]  [0.834, 0.939, 0.0]
# 1               7_layers  [0.827, 0.936, 0.0]  [0.811, 0.942, 0.0]
# 2               3_layers  [0.808, 0.926, 0.0]  [0.777, 0.937, 0.0]
# 3  7_layers_with_dropout  [0.801, 0.915, 0.0]  [0.743, 0.937, 0.0]
#
#               F1 score                         Confusion Matrix
# 0  [0.828, 0.941, 0.0]  [[221, 44, 0], [48, 734, 0], [0, 0, 0]]
# 1  [0.819, 0.939, 0.0]  [[215, 50, 0], [45, 737, 0], [0, 0, 0]]
# 2  [0.792, 0.931, 0.0]  [[206, 59, 0], [49, 733, 0], [0, 0, 0]]
# 3  [0.771, 0.926, 0.0]  [[197, 68, 0], [49, 733, 0], [0, 0, 0]]

# %%
# load dataset
test_df = pd.read_csv("./train.csv")

# Categorizing label
test_df.loc[test_df["label"] == "no_error", "label"] = 0
test_df.loc[test_df["label"] == "knees_forward_error", "label"] = 1

print(f'Number of rows: {test_df.shape[0]} \nNumber of columns: {test_df.shape[1]}\n')
print(f"Labels: \n{test_df['label'].value_counts()}\n")
# Out:
# Number of rows: 5235
# Number of columns: 37
#
# Labels:
# 1    3931
# 0    1304
# Name: label, dtype: int64

# %%
# Standard Scaling of features
test_x = test_df.drop("label", axis = 1)
test_x = pd.DataFrame(sc.transform(test_x))

test_y = test_df["label"]

# # Converting prediction to categorical
test_y_cat = to_categorical(test_y)

# %%
test_set_results = []

for name, model in final_models.items():
    # Evaluate model
    predict_x = model.predict(test_x, verbose=False) 
    y_pred_class = np.argmax(predict_x, axis=1)
    y_test_class = np.argmax(test_y_cat, axis=1)

    cm = confusion_matrix(y_test_class, y_pred_class, labels=[0, 1, 2])
    (p_score, r_score, f_score, _) = precision_recall_fscore_support(y_test_class, y_pred_class, labels=[0, 1, 2])
    
    test_set_results.append(( name, round_up_metric_results(p_score), round_up_metric_results(r_score), round_up_metric_results(f_score), cm ))

test_set_results.sort(key=lambda k: sum(k[3]), reverse=True)
pd.DataFrame(test_set_results, columns=["Model", "Precision Score", "Recall Score", "F1 score", "Confusion Matrix"])
# Out:
#                    Model      Precision Score         Recall Score  \
# 0               5_layers  [0.919, 0.984, 0.0]  [0.952, 0.972, 0.0]
# 1               7_layers  [0.931, 0.976, 0.0]  [0.928, 0.977, 0.0]
# 2               3_layers  [0.925, 0.977, 0.0]  [0.932, 0.975, 0.0]
# 3  7_layers_with_dropout  [0.927, 0.971, 0.0]  [0.911, 0.976, 0.0]
#
#               F1 score                            Confusion Matrix
# 0  [0.936, 0.978, 0.0]  [[1242, 62, 0], [109, 3822, 0], [0, 0, 0]]
# 1  [0.929, 0.977, 0.0]   [[1210, 94, 0], [90, 3841, 0], [0, 0, 0]]
# 2  [0.929, 0.976, 0.0]   [[1215, 89, 0], [98, 3833, 0], [0, 0, 0]]
# 3  [0.919, 0.973, 0.0]  [[1188, 116, 0], [94, 3837, 0], [0, 0, 0]]

# %%
final_models["7_layers"].save("./model/kf_dp.h5")

# %%
for model_name, model in final_models.items():
    model.save(f"./model/{model_name}.h5")
