# %%
import mediapipe as mp
import cv2
import numpy as np
import pandas as pd
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# Drawing helpers
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %%
import csv
import os

# %%
IMPORTANT_LMS = [
"NOSE",
"LEFT_SHOULDER",
"RIGHT_SHOULDER",
"LEFT_HIP",
"RIGHT_HIP",
"LEFT_KNEE",
"RIGHT_KNEE",
"LEFT_ANKLE",
"RIGHT_ANKLE",
]

# Generate all columns of the data frame

HEADERS = ["label"] # Label column

for lm in IMPORTANT_LMS:
    HEADERS += [f"{lm.lower()}_x", f"{lm.lower()}_y", f"{lm.lower()}_z", f"{lm.lower()}_v"]

# %%
def rescale_frame(frame, percent=50):
    '''
    Rescale a frame to a certain percentage compare to its original frame
    '''
    width = int(frame.shape[1] * percent/ 100)
    height = int(frame.shape[0] * percent/ 100)
    dim = (width, height)
    return cv2.resize(frame, dim, interpolation = cv2.INTER_AREA)
    

def init_csv(dataset_path: str):
    '''
    Create a blank csv file with just columns
    '''

    # Ignore if file is already exist
    if os.path.exists(dataset_path):
        return

    # Write all the columns to a empaty file
    with open(dataset_path, mode="w", newline="") as f:
        csv_writer = csv.writer(f, delimiter=",", quotechar='"', quoting=csv.QUOTE_MINIMAL)
        csv_writer.writerow(HEADERS)


def export_landmark_to_csv(dataset_path: str, results, action: str) -> None:
    '''
    Export Labeled Data from detected landmark to csv
    '''
    landmarks = results.pose_landmarks.landmark
    keypoints = []

    try:
        # Extract coordinate of important landmarks
        for lm in IMPORTANT_LMS:
            keypoint = landmarks[mp_pose.PoseLandmark[lm].value]
            keypoints.append([keypoint.x, keypoint.y, keypoint.z, keypoint.visibility])
        
        keypoints = list(np.array(keypoints).flatten())

        # Insert action as the label (first column)
        keypoints.insert(0, action)

        # Append new row to .csv file
        with open(dataset_path, mode="a", newline="") as f:
            csv_writer = csv.writer(f, delimiter=",", quotechar='"', quoting=csv.QUOTE_MINIMAL)
            csv_writer.writerow(keypoints)
        

    except Exception as e:
        print(e)
        pass


def describe_dataset(dataset_path: str):
    '''
    Describe dataset
    '''

    data = pd.read_csv(dataset_path)
    print(f"Headers: {list(data.columns.values)}")
    print(f'Number of rows: {data.shape[0]} \nNumber of columns: {data.shape[1]}\n')
    print(f"Labels: \n{data['label'].value_counts()}\n")
    print(f"Missing values: {data.isnull().values.any()}\n")
    
    duplicate = data[data.duplicated()]
    print(f"Duplicate Rows : {len(duplicate.sum(axis=1))}")

    return data


def remove_duplicate_rows(dataset_path: str):
    '''
    Remove duplicated data from the dataset then save it to another files
    '''
    
    df = pd.read_csv(dataset_path)
    df.drop_duplicates(keep="first", inplace=True)
    df.to_csv(f"cleaned_train.csv", sep=',', encoding='utf-8', index=False)
    

def concat_csv_files_with_same_headers(file_paths: list, saved_path: str):
    '''
    Concat different csv files
    '''
    all_df = []
    for path in file_paths:
        df = pd.read_csv(path, index_col=None, header=0)
        all_df.append(df)
    
    results = pd.concat(all_df, axis=0, ignore_index=True)
    results.to_csv(saved_path, sep=',', encoding='utf-8', index=False)

# %%
DATASET_PATH = "train.csv"
VIDEOS_FOLDER = "./dataset/train/error"

# init_csv(DATASET_PATH)

with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    last_video = None
    for video_file in os.listdir(VIDEOS_FOLDER):
        if not video_file.endswith(".mp4"):
            continue
        
        print(f"Displaying video: {video_file}")
        
        cap = cv2.VideoCapture(os.path.join(VIDEOS_FOLDER, video_file))
        save_counts = 0
        
        while cap.isOpened():
            ret, image = cap.read()

            if not ret:
                break

            # Reduce size of a frame
            image = rescale_frame(image, 60)
            image = cv2.flip(image, 1)

            # Recolor image from BGR to RGB for mediapipe
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False

            results = pose.process(image)

            if not results.pose_landmarks:
                print("No landmarks detected")
                continue

            # Recolor image from BGR to RGB for mediapipe
            image.flags.writeable = True
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # Draw landmarks and connections
            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS, mp_drawing.DrawingSpec(color=(244, 117, 66), thickness=2, circle_radius=4), mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

            # Display the saved count
            cv2.putText(image, f"Saved: {save_counts}", (50, 50), cv2.FONT_HERSHEY_COMPLEX, 2, (0, 0, 0), 2, cv2.LINE_AA)

            cv2.imshow("CV2", image)

            # Pressed key for action
            k = cv2.waitKey(1) & 0xFF

            # Press C to save as correct form
            if k == ord('n'): 
                export_landmark_to_csv(DATASET_PATH, results, "no_error")
                save_counts += 1
            # Press L to save as low back
            elif k == ord("l"):
                export_landmark_to_csv(DATASET_PATH, results, "knees_forward_error")
                save_counts += 1
            # Press q to stop
            elif k == ord("q"):
                break
            else: continue
        
        last_video = video_file
        cap.release()
        cv2.destroyAllWindows()

        # (Optional)Fix bugs cannot close windows in MacOS (https://stackoverflow.com/questions/6116564/destroywindow-does-not-close-window-on-mac-using-python-and-opencv)
        for i in range (1, 5):
            cv2.waitKey(1)

# %%
df = describe_dataset(DATASET_PATH)
# Out:
# Headers: ['label', 'nose_x', 'nose_y', 'nose_z', 'nose_v', 'left_shoulder_x', 'left_shoulder_y', 'left_shoulder_z', 'left_shoulder_v', 'right_shoulder_x', 'right_shoulder_y', 'right_shoulder_z', 'right_shoulder_v', 'left_hip_x', 'left_hip_y', 'left_hip_z', 'left_hip_v', 'right_hip_x', 'right_hip_y', 'right_hip_z', 'right_hip_v', 'left_knee_x', 'left_knee_y', 'left_knee_z', 'left_knee_v', 'right_knee_x', 'right_knee_y', 'right_knee_z', 'right_knee_v', 'left_ankle_x', 'left_ankle_y', 'left_ankle_z', 'left_ankle_v', 'right_ankle_x', 'right_ankle_y', 'right_ankle_z', 'right_ankle_v']
# Number of rows: 5235
# Number of columns: 37
#
# Labels:
# knees_forward_error    3931
# no_error               1304
# Name: label, dtype: int64
#
# Missing values: False
#
# Duplicate Rows : 0

# %%
sns.countplot(x='label', data=df, palette="Set1")
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
DATASET_PATH = "test.csv"
VIDEOS_FOLDER = "./dataset/test/error"

# init_csv(DATASET_PATH)

with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    last_video = None
    for video_file in os.listdir(VIDEOS_FOLDER):
        if not video_file.endswith(".mp4"):
            continue
        
        print(f"Displaying video: {video_file}")
        
        cap = cv2.VideoCapture(os.path.join(VIDEOS_FOLDER, video_file))
        save_counts = 0
        
        while cap.isOpened():
            ret, image = cap.read()

            if not ret:
                break

            # Reduce size of a frame
            image = rescale_frame(image, 60)
            image = cv2.flip(image, 1)

            # Recolor image from BGR to RGB for mediapipe
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False

            results = pose.process(image)

            if not results.pose_landmarks:
                print("No landmarks detected")
                continue

            # Recolor image from BGR to RGB for mediapipe
            image.flags.writeable = True
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # Draw landmarks and connections
            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS, mp_drawing.DrawingSpec(color=(244, 117, 66), thickness=2, circle_radius=4), mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

            # Display the saved count
            cv2.putText(image, f"Saved: {save_counts}", (50, 50), cv2.FONT_HERSHEY_COMPLEX, 2, (0, 0, 0), 2, cv2.LINE_AA)

            cv2.imshow("CV2", image)

            # Pressed key for action
            k = cv2.waitKey(1) & 0xFF

            # Press C to save as correct form
            if k == ord('n'): 
                export_landmark_to_csv(DATASET_PATH, results, "no_error")
                save_counts += 1
            # Press L to save as low back
            elif k == ord("l"):
                export_landmark_to_csv(DATASET_PATH, results, "knees_forward_error")
                save_counts += 1
            # Press q to stop
            elif k == ord("q"):
                break
            else: continue
        
        last_video = video_file
        cap.release()
        cv2.destroyAllWindows()

        # (Optional)Fix bugs cannot close windows in MacOS (https://stackoverflow.com/questions/6116564/destroywindow-does-not-close-window-on-mac-using-python-and-opencv)
        for i in range (1, 5):
            cv2.waitKey(1)
# Out:
# Displaying video: 48771_2.mp4
# Displaying video: 48786_3.mp4
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# Displaying video: 48787_1.mp4
# No landmarks detected
# Displaying video: 48802_1.mp4
# No landmarks detected
# Displaying video: 48809_3.mp4
# Displaying video: 48816_4.mp4
# No landmarks detected
# Displaying video: 48826_1.mp4
# No landmarks detected
# Displaying video: 48834_2.mp4
# No landmarks detected
# Displaying video: 48842_6.mp4
# Displaying video: 48844_1.mp4
# Displaying video: 48851_1.mp4
# No landmarks detected
# Displaying video: 48853_1.mp4
# No landmarks detected
# Displaying video: 48858_1.mp4
# Displaying video: 48859_3.mp4
# No landmarks detected
# No landmarks detected
# Displaying video: 48863_2.mp4
# No landmarks detected
# Displaying video: 48890_1.mp4
# Displaying video: 48911_7.mp4
# Displaying video: 48917_4.mp4
# Displaying video: 48933_2.mp4
# No landmarks detected
# Displaying video: 48979_1.mp4
# Displaying video: 48980_4.mp4
# No landmarks detected
# Displaying video: 48986_4.mp4
# Displaying video: 48993_1.mp4
# Displaying video: 49000_8.mp4
# Displaying video: 49006_2.mp4
# Displaying video: 49042_1.mp4
# Displaying video: 49045_2.mp4
# Displaying video: 49048_3.mp4
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# Displaying video: 
1.mp4
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# Displaying video: 50204_1.mp4
# Displaying video: 50205_4.mp4
# No landmarks detected
# Displaying video: 50210_1.mp4
# Displaying video: 50214_1.mp4
# No landmarks detected
# Displaying video: 50215_21.mp4
# Displaying video: 50218_1.mp4
# Displaying video: 50224_1.mp4
# Displaying video: 50229_3.mp4
# No landmarks detected
# Displaying video: 50238_1.mp4
# Displaying video: 50241_4.mp4
# Displaying video: 50242_3.mp4
# Displaying video: 50262_4.mp4
# Displaying video: 50264_2.mp4
# No landmarks detected
# Displaying video: 50280_3.mp4
# Displaying video: 50284_1.mp4
# No landmarks detected
# No landmarks detected
# Displaying video: 50300_2.mp4
# No landmarks detected
# Displaying video: 50309_4.mp4
# Displaying video: 50312_3.mp4
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# Displaying video: 50320_1.mp4
# No landmarks detected
# Displaying video: 50325_1.mp4
# Displaying video: 50326_1.mp4
# No landmarks detected
# Displaying video: 50331_4.mp4
# No landmarks detected
# Displaying video: 50342_3.mp4
# Displaying video: 50343_1.mp4
# Displaying video: 50352_2.mp4
# Displaying video: 50360_2.mp4
# Displaying video: 50370_3.mp4
# No landmarks detected
# Displaying video: 50373_5.mp4
# Displaying video: 50395_2.mp4
# No landmarks detected
# Displaying video: 50400_2.mp4
# Displaying video: 50406_1.mp4
# Displaying video: 50423_5.mp4
# Displaying video: 50428_1.mp4
# Displaying video: 50435_1.mp4
# Displaying video: 50436_1.mp4
# Displaying video: 50438_3.mp4
# Displaying video: 50471_3.mp4
# Displaying video: 50477_3.mp4
# No landmarks detected
# Displaying video: 50489_2.mp4
# No landmarks detected
# Displaying video: 50492_2.mp4
# No landmarks detected
# Displaying video: 50499_1.mp4
# No landmarks detected
# Displaying video: 50504_8.mp4
# No landmarks detected
# Displaying video: 50505_2.mp4
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# Displaying video: 50512_1.mp4
# No landmarks detected
# Displaying video: 50515_2.mp4
# No landmarks detected
# Displaying video: 50520_5.mp4
# Displaying video: 50530_1.mp4
# Displaying video: 50534_16.mp4
# Displaying video: 50544_3.mp4
# Displaying video: 50550_1.mp4
# Displaying video: 50561_1.mp4
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# Displaying video: 50571_4.mp4
# No landmarks detected
# Displaying video: 50575_2.mp4
# Displaying video: 50578_5.mp4
# No landmarks detected
# Displaying video: 50582_2.mp4
# Displaying video: 50583_5.mp4
# No landmarks detected
# Displaying video: 50590_2.mp4
# Displaying video: 50591_1.mp4
# Displaying video: 50599_3.mp4
# Displaying video: 50601_2.mp4
# Displaying video: 50606_1.mp4
# No landmarks detected
# No landmarks detected
# No landmarks detected
# Displaying video: 50617_2.mp4
# No landmarks detected
# Displaying video: 50619_4.mp4
# Displaying video: 50631_2.mp4
# Displaying video: 50635_1.mp4
# No landmarks detected
# Displaying video: 50636_2.mp4
# Displaying video: 50651_4.mp4
# No landmarks detected
# Displaying video: 50706_1.mp4
# No landmarks detected
# Displaying video: 50709_3.mp4
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# No landmarks detected
# Displaying video: 50717_1.mp4
# Displaying video: 50739_1.mp4
# Displaying video: 50743_4.mp4
# Displaying video: 50745_1.mp4
# Displaying video: 50750_1.mp4
# Displaying video: 50762_2.mp4
# Displaying video: 50772_5.mp4
# Displaying video: 50790_1.mp4
# No landmarks detected
# Displaying video: 50805_1.mp4
# No landmarks detected
# Displaying video: 50810_1.mp4
# Displaying video: 50816_3.mp4
# Displaying video: 50818_5.mp4

# %%
test_df = describe_dataset(DATASET_PATH)
# Out:
# Headers: ['label', 'nose_x', 'nose_y', 'nose_z', 'nose_v', 'left_shoulder_x', 'left_shoulder_y', 'left_shoulder_z', 'left_shoulder_v', 'right_shoulder_x', 'right_shoulder_y', 'right_shoulder_z', 'right_shoulder_v', 'left_hip_x', 'left_hip_y', 'left_hip_z', 'left_hip_v', 'right_hip_x', 'right_hip_y', 'right_hip_z', 'right_hip_v', 'left_knee_x', 'left_knee_y', 'left_knee_z', 'left_knee_v', 'right_knee_x', 'right_knee_y', 'right_knee_z', 'right_knee_v', 'left_ankle_x', 'left_ankle_y', 'left_ankle_z', 'left_ankle_v', 'right_ankle_x', 'right_ankle_y', 'right_ankle_z', 'right_ankle_v']
# Number of rows: 2525
# Number of columns: 37
#
# Labels:
# knees_forward_error    1637
# no_error                888
# Name: label, dtype: int64
#
# Missing values: False
#
# Duplicate Rows : 0

# %%
sns.countplot(y='label', data=test_df, palette="Set1")
# Out:
# <AxesSubplot:xlabel='count', ylabel='label'>
