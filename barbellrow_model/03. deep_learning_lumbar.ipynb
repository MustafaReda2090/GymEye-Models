# %%
# Data visualization
import numpy as np
import pandas as pd 

# Keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.optimizers import Adam
from keras.utils.np_utils import to_categorical
from keras.callbacks import EarlyStopping
import keras_tuner as kt

# Train-Test
from sklearn.model_selection import train_test_split
# Classification Report
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support

import pickle

import warnings
warnings.filterwarnings('ignore')

# %%
# Determine important landmarks for barbell row
IMPORTANT_LMS = [
    "NOSE",
    "LEFT_SHOULDER",
    "RIGHT_SHOULDER",
    "LEFT_ELBOW",
    "RIGHT_ELBOW",
    "LEFT_WRIST",
    "RIGHT_WRIST",
    "LEFT_HIP",
    "RIGHT_HIP",
    "LEFT_KNEE",
    "RIGHT_KNEE",
    "LEFT_ANKLE",
    "RIGHT_ANKLE",
]

# Generate all columns of the data frame
HEADERS = ["label"]  # Label column

for lm in IMPORTANT_LMS:
    HEADERS += [f"{lm.lower()}_x", f"{lm.lower()}_y", f"{lm.lower()}_z", f"{lm.lower()}_v"]

# %%
def describe_dataset(dataset_path: str):
    '''
    Describe dataset
    '''

    data = pd.read_csv(dataset_path)
    print(f"Headers: {list(data.columns.values)}")
    print(f'Number of rows: {data.shape[0]} \nNumber of columns: {data.shape[1]}\n')
    print(f"Labels: \n{data['label'].value_counts()}\n")
    print(f"Missing values: {data.isnull().values.any()}\n")
    
    duplicate = data[data.duplicated()]
    print(f"Duplicate Rows : {len(duplicate.sum(axis=1))}")

    return data


# Remove duplicate rows (optional)
def remove_duplicate_rows(dataset_path: str):
    '''
    Remove duplicated data from the dataset then save it to another files
    '''
    
    df = pd.read_csv(dataset_path)
    df.drop_duplicates(keep="first", inplace=True)
    df.to_csv(f"cleaned_train.csv", sep=',', encoding='utf-8', index=False)


def round_up_metric_results(results) -> list:
    '''Round up metrics results such as precision score, recall score, ...'''
    return list(map(lambda el: round(el, 3), results))


df01 = describe_dataset("./lumbar_train.csv")
# Out:
# Headers: ['label', 'nose_x', 'nose_y', 'nose_z', 'nose_v', 'left_shoulder_x', 'left_shoulder_y', 'left_shoulder_z', 'left_shoulder_v', 'right_shoulder_x', 'right_shoulder_y', 'right_shoulder_z', 'right_shoulder_v', 'left_elbow_x', 'left_elbow_y', 'left_elbow_z', 'left_elbow_v', 'right_elbow_x', 'right_elbow_y', 'right_elbow_z', 'right_elbow_v', 'left_wrist_x', 'left_wrist_y', 'left_wrist_z', 'left_wrist_v', 'right_wrist_x', 'right_wrist_y', 'right_wrist_z', 'right_wrist_v', 'left_hip_x', 'left_hip_y', 'left_hip_z', 'left_hip_v', 'right_hip_x', 'right_hip_y', 'right_hip_z', 'right_hip_v', 'left_knee_x', 'left_knee_y', 'left_knee_z', 'left_knee_v', 'right_knee_x', 'right_knee_y', 'right_knee_z', 'right_knee_v', 'left_ankle_x', 'left_ankle_y', 'left_ankle_z', 'left_ankle_v', 'right_ankle_x', 'right_ankle_y', 'right_ankle_z', 'right_ankle_v']
# Number of rows: 5891
# Number of columns: 53
#
# Labels:
# lumbar_correct    5001
# lumbar_error       890
# Name: label, dtype: int64
#
# Missing values: False
#
# Duplicate Rows : 0

# %%
# load dataset
df = describe_dataset("./lumbar_train.csv")
# Categorizing label
df.loc[df["label"] == "lumbar_correct", "label"] = 0
df.loc[df["label"] == "lumbar_error", "label"] = 1
# Out:
# Headers: ['label', 'nose_x', 'nose_y', 'nose_z', 'nose_v', 'left_shoulder_x', 'left_shoulder_y', 'left_shoulder_z', 'left_shoulder_v', 'right_shoulder_x', 'right_shoulder_y', 'right_shoulder_z', 'right_shoulder_v', 'left_elbow_x', 'left_elbow_y', 'left_elbow_z', 'left_elbow_v', 'right_elbow_x', 'right_elbow_y', 'right_elbow_z', 'right_elbow_v', 'left_wrist_x', 'left_wrist_y', 'left_wrist_z', 'left_wrist_v', 'right_wrist_x', 'right_wrist_y', 'right_wrist_z', 'right_wrist_v', 'left_hip_x', 'left_hip_y', 'left_hip_z', 'left_hip_v', 'right_hip_x', 'right_hip_y', 'right_hip_z', 'right_hip_v', 'left_knee_x', 'left_knee_y', 'left_knee_z', 'left_knee_v', 'right_knee_x', 'right_knee_y', 'right_knee_z', 'right_knee_v', 'left_ankle_x', 'left_ankle_y', 'left_ankle_z', 'left_ankle_v', 'right_ankle_x', 'right_ankle_y', 'right_ankle_z', 'right_ankle_v']
# Number of rows: 5891
# Number of columns: 53
#
# Labels:
# lumbar_correct    5001
# lumbar_error       890
# Name: label, dtype: int64
#
# Missing values: False
#
# Duplicate Rows : 0

# %%
# Standard Scaling of features
# Dump input scaler
with open("./model/input_scaler_lumbar.pkl", "rb") as f2:
    sc = pickle.load(f2)   

x = df.drop("label", axis = 1)
x = pd.DataFrame(sc.transform(x))

y = df["label"]

# # Converting prediction to categorical
y_cat = to_categorical(y)

# %%
x_train, x_test, y_train, y_test = train_test_split(x.values, y_cat, test_size=0.2, random_state=1234)

# %%
stop_early = EarlyStopping(monitor='loss', patience=3)

# Final Results
final_models = {}

# %%
def describe_model(model):
    '''
    Describe Model architecture
    '''
    print(f"Describe models architecture")
    for i, layer in enumerate(model.layers):
        number_of_units = layer.units if hasattr(layer, 'units') else 0

        if hasattr(layer, "activation"):
            print(f"Layer-{i + 1}: {number_of_units} units, func: ", layer.activation)
        else:
            print(f"Layer-{i + 1}: {number_of_units} units, func: None")
            

def get_best_model(tuner):
    '''
    Describe and return the best model found from keras tuner
    '''
    best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
    best_model = tuner.hypermodel.build(best_hps)

    describe_model(best_model)

    print("\nOther params:")
    ignore_params = ["tuner", "activation", "layer", "epoch"]
    for param, value in best_hps.values.items():
        if not any(word in param for word in ignore_params):
            print(f"{param}: {value}")

    return best_model

# %%
def model_3l_builder(hp):
    model = Sequential()
    model.add(Dense(52, input_dim = 52, activation = "relu"))

    hp_activation = hp.Choice('activation', values=['relu', 'tanh'])
    hp_layer_1 = hp.Int('layer_1', min_value=32, max_value=512, step=32)
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.add(Dense(units=hp_layer_1, activation=hp_activation))
    model.add(Dense(2, activation = "softmax"))

    model.compile(optimizer=Adam(learning_rate=hp_learning_rate), loss="categorical_crossentropy", metrics = ["accuracy"])
    
    return model

# %%
tuner_3l_lumbar = kt.Hyperband(
    model_3l_builder,
    objective='accuracy',
    max_epochs=10,
    directory='keras_tuner_dir',
    project_name='keras_tuner_demo'
)
tuner_3l_lumbar.search(x_train, y_train, epochs=10, callbacks=[stop_early])
# Out:
# Trial 30 Complete [00h 00m 04s]
# accuracy: 0.9004669189453125
#
# Best accuracy So Far: 0.950764000415802
# Total elapsed time: 00h 01m 09s
# INFO:tensorflow:Oracle triggered exit

# %%
model_3l = get_best_model(tuner_3l_lumbar)
model_3l.fit(x_train, y_train, epochs=100, batch_size=10, validation_data=(x_test, y_test), callbacks=[stop_early])
# Out:
# Describe models architecture
# Layer-1: 52 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-2: 320 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-3: 2 units, func:  <function softmax at 0x000001C3932F0F70>
#
# Other params:
# learning_rate: 0.001
# Epoch 1/100
# 472/472 [==============================] - 2s 3ms/step - loss: 0.2873 - accuracy: 0.8890 - val_loss: 0.2611 - val_accuracy: 0.8931
# Epoch 2/100
# 472/472 [==============================] - 1s 2ms/step - loss: 0.2394 - accuracy: 0.9079 - val_loss: 0.2531 - val_accuracy: 0.8872
# Epoch 3/100
# 472/472 [==============================] - 1s 3ms/step - loss: 0.2283 - accuracy: 0.9111 - val_loss: 0.2433 - val_accuracy: 0.8957
# Epoch 4/100
# 472/472 [==============================] - 2s 3ms/step - loss: 0.2144 - accuracy: 0.9145 - val_loss: 0.2248 - val_accuracy: 0.9109
# Epoch 5/100
# 472/472 [==============================] - 1s 2ms/step - loss: 0.1995 - accuracy: 0.9219 - val_loss: 0.2245 - val_accuracy: 0.9101
# Epoch 6/100
# 472/472 [==============================] - 1s 3ms/step - loss: 0.1880 - accuracy: 0.9293 - val_loss: 0.2098 - val_accuracy: 0.9194
# Epoch 7/100
# 472/472 [==============================] - 1s 3ms/step - loss: 0.1734 - accuracy: 0.9329 - val_loss: 0.2152 - val_accuracy: 0.9228
# Epoch 8/100
# 472/472 [==============================] - 1s 2ms/step - loss: 0.1596 - accuracy: 0.9382 - val_loss: 0.2192 - val_accuracy: 0.9186
# Epoch 9/100
# 472/472 [==============================] - 1s 2ms/step - loss: 0.1412 - accuracy: 0.9448 - val_loss: 0.2406 - val_accuracy: 0.9118
# Epoch 10/100
# 472/472 [==============================] - 1s 2ms/step - loss: 0.1307 - accuracy: 0.9510 - val_loss: 0.2018 - val_accuracy: 0.9271
# Epoch 11/100
# 472/472 [==============================] - 1s 3ms/step - loss: 0.1167 - accuracy: 0.9550 - val_loss: 0.2052 - val_accuracy: 0.9271
# Epoch 12/100
# 472/472 [==============================] - 1s 3ms/step - loss: 0.1021 - accuracy: 0.9622 - val_loss: 0.2172 - val_accuracy: 0.9271
# Epoch 13/100
# 472/472 [==============================] - 1s 3ms/step - loss: 0.0965 - accuracy: 0.9650 - val_loss: 0.2138 - val_accuracy: 0.9237
# Epoch 14/100
# 472/472 [==============================] - 1s 3ms/step - loss: 0.0846 - accuracy: 0.9682 - val_loss: 0.2043 - val_accuracy: 0.9406
# Epoch 15/100
# 472/472 [==============================] - 1s 2ms/step - loss: 0.0708 - accuracy: 0.9760 - val_loss: 0.2362 - val_accuracy: 0.9279
# Epoch 16/100
# 472/472 [==============================] - 1s 2ms/step - loss: 0.0646 - accuracy: 0.9747 - val_loss: 0.2453 - val_accuracy: 0.9271
# Epoch 17/100
# 472/472 [==============================] - 1s 2ms/step - loss: 0.0619 - accuracy: 0.9779 - val_loss: 0.2512 - val_accuracy: 0.9321
# Epoch 18/100
# 472/472 [==============================] - 1s 2ms/step - loss: 0.0534 - accuracy: 0.9798 - val_loss: 0.2722 - val_accuracy: 0.9389
# Epoch 19/100
# 472/472 [==============================] - 1s 2ms/step - loss: 0.0483 - accuracy: 0.9826 - val_loss: 0.2240 - val_accuracy: 0.9321
# Epoch 20/100
# 472/472 [==============================] - 1s 3ms/step - loss: 0.0419 - accuracy: 0.9854 - val_loss: 0.2340 - val_accuracy: 0.9432
# Epoch 21/100
# 472/472 [==============================] - 1s 3ms/step - loss: 0.0401 - accuracy: 0.9864 - val_loss: 0.2666 - val_accuracy: 0.9389
# Epoch 22/100
# 472/472 [==============================] - 1s 2ms/step - loss: 0.0297 - accuracy: 0.9896 - val_loss: 0.2799 - val_accuracy: 0.9279
# Epoch 23/100
# 472/472 [==============================] - 1s 2ms/step - loss: 0.0322 - accuracy: 0.9894 - val_loss: 0.2946 - val_accuracy: 0.9355
# Epoch 24/100
# 472/472 [==============================] - 1s 2ms/step - loss: 0.0557 - accuracy: 0.9828 - val_loss: 0.2991 - val_accuracy: 0.9372
# Epoch 25/100
# 472/472 [==============================] - 1s 2ms/step - loss: 0.0268 - accuracy: 0.9919 - val_loss: 0.3144 - val_accuracy: 0.9355
# Epoch 26/100
# 472/472 [==============================] - 1s 2ms/step - loss: 0.0195 - accuracy: 0.9955 - val_loss: 0.2600 - val_accuracy: 0.9440
# Epoch 27/100
# 472/472 [==============================] - 1s 2ms/step - loss: 0.0131 - accuracy: 0.9972 - val_loss: 0.2782 - val_accuracy: 0.9398
# Epoch 28/100
# 472/472 [==============================] - 1s 2ms/step - loss: 0.0305 - accuracy: 0.9894 - val_loss: 0.3325 - val_accuracy: 0.9288
# Epoch 29/100
# 472/472 [==============================] - 1s 2ms/step - loss: 0.0199 - accuracy: 0.9936 - val_loss: 0.2951 - val_accuracy: 0.9321
# Epoch 30/100
# 472/472 [==============================] - 1s 3ms/step - loss: 0.0203 - accuracy: 0.9947 - val_loss: 0.3062 - val_accuracy: 0.9296

# %%
final_models["3_layers_lumbar"] = model_3l

# %%
def model_5l_builder(hp):
    model = Sequential()
    model.add(Dense(52, input_dim = 52, activation = "relu"))

    hp_activation = hp.Choice('activation', values=['relu', 'tanh'])
    hp_layer_1 = hp.Int('layer_1', min_value=32, max_value=512, step=32)
    hp_layer_2 = hp.Int('layer_2', min_value=32, max_value=512, step=32)
    hp_layer_3 = hp.Int('layer_3', min_value=32, max_value=512, step=32)
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.add(Dense(units=hp_layer_1, activation=hp_activation))
    model.add(Dense(units=hp_layer_2, activation=hp_activation))
    model.add(Dense(units=hp_layer_3, activation=hp_activation))
    model.add(Dense(2, activation = "softmax"))

    model.compile(optimizer=Adam(learning_rate=hp_learning_rate), loss="categorical_crossentropy", metrics = ["accuracy"])
    
    return model

# %%
import keras
tuner_5l_lumbar = kt.Hyperband(
    model_5l_builder,
    objective='accuracy',
    max_epochs=10,
    directory='keras_tuner_dir',
    project_name='keras_tuner_demo_2'
)

tuner_5l_lumbar.search(
    x_train, 
    y_train, 
    epochs=10, 
    callbacks=[keras.callbacks.EarlyStopping(patience=5)]
)
# Out:
# Trial 30 Complete [00h 00m 13s]
# accuracy: 0.9115025401115417
#
# Best accuracy So Far: 0.9615874290466309
# Total elapsed time: 00h 02m 00s
# INFO:tensorflow:Oracle triggered exit

# %%
model_5l = get_best_model(tuner_5l_lumbar)
model_5l.fit(x_train, y_train, epochs=100, batch_size=10, validation_data=(x_test, y_test), callbacks=[stop_early])
# Out:
# Describe models architecture
# Layer-1: 52 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-2: 256 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-3: 512 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-4: 32 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-5: 2 units, func:  <function softmax at 0x000001C3932F0F70>
#
# Other params:
# learning_rate: 0.001
# Epoch 1/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.2926 - accuracy: 0.8846 - val_loss: 0.2522 - val_accuracy: 0.8957
# Epoch 2/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.2416 - accuracy: 0.9060 - val_loss: 0.2514 - val_accuracy: 0.9042
# Epoch 3/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.2196 - accuracy: 0.9130 - val_loss: 0.2436 - val_accuracy: 0.9084
# Epoch 4/100
# 472/472 [==============================] - 2s 3ms/step - loss: 0.2075 - accuracy: 0.9172 - val_loss: 0.2164 - val_accuracy: 0.9059
# Epoch 5/100
# 472/472 [==============================] - 2s 3ms/step - loss: 0.1862 - accuracy: 0.9249 - val_loss: 0.2133 - val_accuracy: 0.9135
# Epoch 6/100
# 472/472 [==============================] - 2s 3ms/step - loss: 0.1718 - accuracy: 0.9325 - val_loss: 0.2223 - val_accuracy: 0.9135
# Epoch 7/100
# 472/472 [==============================] - 1s 3ms/step - loss: 0.1555 - accuracy: 0.9397 - val_loss: 0.2464 - val_accuracy: 0.9126
# Epoch 8/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.1477 - accuracy: 0.9399 - val_loss: 0.2311 - val_accuracy: 0.9177
# Epoch 9/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.1253 - accuracy: 0.9489 - val_loss: 0.2379 - val_accuracy: 0.9194
# Epoch 10/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.1205 - accuracy: 0.9495 - val_loss: 0.2527 - val_accuracy: 0.9118
# Epoch 11/100
# 472/472 [==============================] - 2s 3ms/step - loss: 0.1137 - accuracy: 0.9552 - val_loss: 0.2471 - val_accuracy: 0.9237
# Epoch 12/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.0995 - accuracy: 0.9590 - val_loss: 0.2306 - val_accuracy: 0.9288
# Epoch 13/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.0975 - accuracy: 0.9633 - val_loss: 0.2567 - val_accuracy: 0.9203
# Epoch 14/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.0880 - accuracy: 0.9656 - val_loss: 0.2705 - val_accuracy: 0.9092
# Epoch 15/100
# 472/472 [==============================] - 2s 3ms/step - loss: 0.0779 - accuracy: 0.9690 - val_loss: 0.2785 - val_accuracy: 0.9330
# Epoch 16/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.0701 - accuracy: 0.9745 - val_loss: 0.2502 - val_accuracy: 0.9288
# Epoch 17/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.0745 - accuracy: 0.9724 - val_loss: 0.2819 - val_accuracy: 0.9271
# Epoch 18/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.0697 - accuracy: 0.9756 - val_loss: 0.2358 - val_accuracy: 0.9381
# Epoch 19/100
# 472/472 [==============================] - 3s 6ms/step - loss: 0.0539 - accuracy: 0.9792 - val_loss: 0.2796 - val_accuracy: 0.9330
# Epoch 20/100
# 472/472 [==============================] - 3s 6ms/step - loss: 0.0531 - accuracy: 0.9807 - val_loss: 0.2948 - val_accuracy: 0.9313
# Epoch 21/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.0510 - accuracy: 0.9820 - val_loss: 0.3270 - val_accuracy: 0.9347
# Epoch 22/100
# 472/472 [==============================] - 3s 6ms/step - loss: 0.0565 - accuracy: 0.9807 - val_loss: 0.3563 - val_accuracy: 0.9254
# Epoch 23/100
# 472/472 [==============================] - 3s 7ms/step - loss: 0.0412 - accuracy: 0.9868 - val_loss: 0.3644 - val_accuracy: 0.9237
# Epoch 24/100
# 472/472 [==============================] - 3s 7ms/step - loss: 0.0604 - accuracy: 0.9830 - val_loss: 0.3075 - val_accuracy: 0.9279
# Epoch 25/100
# 472/472 [==============================] - 3s 7ms/step - loss: 0.0359 - accuracy: 0.9864 - val_loss: 0.3468 - val_accuracy: 0.9203
# Epoch 26/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.0417 - accuracy: 0.9837 - val_loss: 0.3515 - val_accuracy: 0.9220
# Epoch 27/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.0352 - accuracy: 0.9847 - val_loss: 0.3954 - val_accuracy: 0.9288
# Epoch 28/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.0320 - accuracy: 0.9894 - val_loss: 0.3199 - val_accuracy: 0.9381
# Epoch 29/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.0258 - accuracy: 0.9915 - val_loss: 0.3456 - val_accuracy: 0.9347
# Epoch 30/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.0351 - accuracy: 0.9894 - val_loss: 0.2880 - val_accuracy: 0.9338
# Epoch 31/100
# 472/472 [==============================] - 3s 7ms/step - loss: 0.0296 - accuracy: 0.9909 - val_loss: 0.3355 - val_accuracy: 0.9296
# Epoch 32/100
# 472/472 [==============================] - 3s 6ms/step - loss: 0.0352 - accuracy: 0.9890 - val_loss: 0.3397 - val_accuracy: 0.9338

# %%
final_models["5_layers_lumbar"] = model_5l

# %%
def model_7lD_builder(hp):
    model = Sequential()
    model.add(Dense(52, input_dim = 52, activation = "relu"))

    hp_activation = hp.Choice('activation', values=['relu', 'tanh'])
    hp_layer_1 = hp.Int('layer_1', min_value=32, max_value=512, step=32)
    hp_layer_2 = hp.Int('layer_2', min_value=32, max_value=512, step=32)
    hp_layer_3 = hp.Int('layer_3', min_value=32, max_value=512, step=32)
    hp_dropout_1 = hp.Float('dropout_1', min_value=0.1, max_value=0.5, step=0.1)
    hp_dropout_2 = hp.Float('dropout_2', min_value=0.1, max_value=0.5, step=0.1)
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.add(Dense(units=hp_layer_1, activation=hp_activation))
    model.add(Dropout(rate=hp_dropout_1))
    model.add(Dense(units=hp_layer_2, activation=hp_activation))
    model.add(Dropout(rate=hp_dropout_2))
    model.add(Dense(units=hp_layer_3, activation=hp_activation))
    model.add(Dense(2, activation = "softmax"))

    model.compile(optimizer=Adam(learning_rate=hp_learning_rate), loss="categorical_crossentropy", metrics = ["accuracy"])
    
    return model

# %%
tuner_7lD_lumbar = kt.Hyperband(
    model_7lD_builder,
    objective='accuracy',
    max_epochs=10,
    directory='keras_tuner_dir',
    project_name='keras_tuner_demo_3'
)
tuner_7lD_lumbar.search(x_train, y_train, epochs=10, callbacks=[keras.callbacks.EarlyStopping(patience=5)])
# Out:
# Trial 30 Complete [00h 00m 06s]
# accuracy: 0.8885823488235474
#
# Best accuracy So Far: 0.9514006972312927
# Total elapsed time: 00h 02m 07s
# INFO:tensorflow:Oracle triggered exit

# %%
model_7lD = get_best_model(tuner_7lD_lumbar)
model_7lD.fit(x_train, y_train, epochs=100, batch_size=10, validation_data=(x_test, y_test), callbacks=[stop_early])
# Out:
# Describe models architecture
# Layer-1: 52 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-2: 448 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-3: 0 units, func: None
# Layer-4: 352 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-5: 0 units, func: None
# Layer-6: 480 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-7: 2 units, func:  <function softmax at 0x000001C3932F0F70>
#
# Other params:
# dropout_1: 0.1
# dropout_2: 0.4
# learning_rate: 0.001
# Epoch 1/100
# 472/472 [==============================] - 3s 6ms/step - loss: 0.3086 - accuracy: 0.8733 - val_loss: 0.2571 - val_accuracy: 0.8906
# Epoch 2/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.2552 - accuracy: 0.8966 - val_loss: 0.2533 - val_accuracy: 0.8999
# Epoch 3/100
# 472/472 [==============================] - 3s 5ms/step - loss: 0.2441 - accuracy: 0.9064 - val_loss: 0.2594 - val_accuracy: 0.9016
# Epoch 4/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.2220 - accuracy: 0.9115 - val_loss: 0.2185 - val_accuracy: 0.9152
# Epoch 5/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.2045 - accuracy: 0.9215 - val_loss: 0.2269 - val_accuracy: 0.9084
# Epoch 6/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.1921 - accuracy: 0.9228 - val_loss: 0.2410 - val_accuracy: 0.9220
# Epoch 7/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.1687 - accuracy: 0.9336 - val_loss: 0.2201 - val_accuracy: 0.9279
# Epoch 8/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.1639 - accuracy: 0.9329 - val_loss: 0.2294 - val_accuracy: 0.9160
# Epoch 9/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.1463 - accuracy: 0.9408 - val_loss: 0.2644 - val_accuracy: 0.9084
# Epoch 10/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.1353 - accuracy: 0.9459 - val_loss: 0.2541 - val_accuracy: 0.9271
# Epoch 11/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.1256 - accuracy: 0.9495 - val_loss: 0.2994 - val_accuracy: 0.9237
# Epoch 12/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.1125 - accuracy: 0.9559 - val_loss: 0.2263 - val_accuracy: 0.9288
# Epoch 13/100
# 472/472 [==============================] - 3s 5ms/step - loss: 0.1142 - accuracy: 0.9567 - val_loss: 0.2413 - val_accuracy: 0.9220
# Epoch 14/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.1033 - accuracy: 0.9588 - val_loss: 0.2523 - val_accuracy: 0.9338
# Epoch 15/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.0931 - accuracy: 0.9650 - val_loss: 0.2467 - val_accuracy: 0.9415
# Epoch 16/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.0843 - accuracy: 0.9667 - val_loss: 0.2522 - val_accuracy: 0.9355
# Epoch 17/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.0824 - accuracy: 0.9694 - val_loss: 0.3002 - val_accuracy: 0.9220
# Epoch 18/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.0821 - accuracy: 0.9697 - val_loss: 0.2785 - val_accuracy: 0.9449
# Epoch 19/100
# 472/472 [==============================] - 3s 7ms/step - loss: 0.0588 - accuracy: 0.9764 - val_loss: 0.3479 - val_accuracy: 0.9381
# Epoch 20/100
# 472/472 [==============================] - 3s 7ms/step - loss: 0.0565 - accuracy: 0.9792 - val_loss: 0.4495 - val_accuracy: 0.9330
# Epoch 21/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.0557 - accuracy: 0.9788 - val_loss: 0.3716 - val_accuracy: 0.9389
# Epoch 22/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.0736 - accuracy: 0.9733 - val_loss: 0.3067 - val_accuracy: 0.9347
# Epoch 23/100
# 472/472 [==============================] - 3s 6ms/step - loss: 0.0646 - accuracy: 0.9756 - val_loss: 0.2886 - val_accuracy: 0.9304
# Epoch 24/100
# 472/472 [==============================] - 3s 7ms/step - loss: 0.0497 - accuracy: 0.9837 - val_loss: 0.3773 - val_accuracy: 0.9381
# Epoch 25/100
# 472/472 [==============================] - 3s 6ms/step - loss: 0.0513 - accuracy: 0.9801 - val_loss: 0.3332 - val_accuracy: 0.9449
# Epoch 26/100
# 472/472 [==============================] - 3s 7ms/step - loss: 0.0597 - accuracy: 0.9773 - val_loss: 0.3365 - val_accuracy: 0.9372
# Epoch 27/100
# 472/472 [==============================] - 3s 7ms/step - loss: 0.0495 - accuracy: 0.9815 - val_loss: 0.3163 - val_accuracy: 0.9372
# Epoch 28/100
# 472/472 [==============================] - 3s 6ms/step - loss: 0.0470 - accuracy: 0.9813 - val_loss: 0.3088 - val_accuracy: 0.9372
# Epoch 29/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.0420 - accuracy: 0.9858 - val_loss: 0.4147 - val_accuracy: 0.9389
# Epoch 30/100
# 472/472 [==============================] - 3s 7ms/step - loss: 0.0516 - accuracy: 0.9830 - val_loss: 0.3932 - val_accuracy: 0.9415
# Epoch 31/100
# 472/472 [==============================] - 3s 7ms/step - loss: 0.0523 - accuracy: 0.9828 - val_loss: 0.3234 - val_accuracy: 0.9415
# Epoch 32/100
# 472/472 [==============================] - 3s 7ms/step - loss: 0.0522 - accuracy: 0.9834 - val_loss: 0.2972 - val_accuracy: 0.9449

# %%
final_models["7_layers_with_dropout_lumbar"] = model_7lD

# %%
def model_7l_builder(hp):
    model = Sequential()
    model.add(Dense(52, input_dim = 52, activation = "relu"))

    hp_activation = hp.Choice('activation', values=['relu', 'tanh'])
    hp_layer_1 = hp.Int('layer_1', min_value=32, max_value=512, step=32)
    hp_layer_2 = hp.Int('layer_2', min_value=32, max_value=512, step=32)
    hp_layer_3 = hp.Int('layer_3', min_value=32, max_value=512, step=32)
    hp_layer_4 = hp.Int('layer_4', min_value=32, max_value=512, step=32)
    hp_layer_5 = hp.Int('layer_5', min_value=32, max_value=512, step=32)
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.add(Dense(units=hp_layer_1, activation=hp_activation))
    model.add(Dense(units=hp_layer_2, activation=hp_activation))
    model.add(Dense(units=hp_layer_3, activation=hp_activation))
    model.add(Dense(units=hp_layer_4, activation=hp_activation))
    model.add(Dense(units=hp_layer_5, activation=hp_activation))
    model.add(Dense(2, activation = "softmax"))

    model.compile(optimizer=Adam(learning_rate=hp_learning_rate), loss="categorical_crossentropy", metrics = ["accuracy"])
    
    return model

# %%
tuner_7l_lumbar = kt.Hyperband(
    model_7l_builder,
    objective='accuracy',
    max_epochs=10,
    directory='keras_tuner_dir',
    project_name='keras_tuner_demo_6'
)
tuner_7l_lumbar.search(x_train, y_train, epochs=10, callbacks=[keras.callbacks.EarlyStopping(patience=5)])
# Out:
# Trial 30 Complete [00h 00m 08s]
# accuracy: 0.9399405717849731
#
# Best accuracy So Far: 0.9541596174240112
# Total elapsed time: 00h 02m 40s
# INFO:tensorflow:Oracle triggered exit

# %%
model_7l = get_best_model(tuner_7l_lumbar)
model_7l.fit(x_train, y_train, epochs=100, batch_size=10, validation_data=(x_test, y_test), callbacks=[stop_early])
# Out:
# Describe models architecture
# Layer-1: 52 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-2: 64 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-3: 352 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-4: 352 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-5: 128 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-6: 384 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-7: 2 units, func:  <function softmax at 0x000001C3932F0F70>
#
# Other params:
# learning_rate: 0.001
# Epoch 1/100
# 472/472 [==============================] - 3s 5ms/step - loss: 0.3044 - accuracy: 0.8854 - val_loss: 0.2524 - val_accuracy: 0.8957
# Epoch 2/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.2569 - accuracy: 0.9017 - val_loss: 0.2406 - val_accuracy: 0.9016
# Epoch 3/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.2372 - accuracy: 0.9107 - val_loss: 0.2434 - val_accuracy: 0.8965
# Epoch 4/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.2223 - accuracy: 0.9115 - val_loss: 0.2304 - val_accuracy: 0.9152
# Epoch 5/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.2073 - accuracy: 0.9213 - val_loss: 0.2248 - val_accuracy: 0.9194
# Epoch 6/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.1945 - accuracy: 0.9272 - val_loss: 0.2090 - val_accuracy: 0.9220
# Epoch 7/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.1790 - accuracy: 0.9310 - val_loss: 0.2089 - val_accuracy: 0.9262
# Epoch 8/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.1679 - accuracy: 0.9334 - val_loss: 0.2364 - val_accuracy: 0.9194
# Epoch 9/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.1495 - accuracy: 0.9425 - val_loss: 0.2999 - val_accuracy: 0.9084
# Epoch 10/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.1502 - accuracy: 0.9425 - val_loss: 0.3250 - val_accuracy: 0.9186
# Epoch 11/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.1357 - accuracy: 0.9514 - val_loss: 0.2407 - val_accuracy: 0.9245
# Epoch 12/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.1225 - accuracy: 0.9527 - val_loss: 0.2472 - val_accuracy: 0.9271
# Epoch 13/100
# 472/472 [==============================] - 3s 5ms/step - loss: 0.1177 - accuracy: 0.9565 - val_loss: 0.2553 - val_accuracy: 0.9228
# Epoch 14/100
# 472/472 [==============================] - 4s 8ms/step - loss: 0.1134 - accuracy: 0.9612 - val_loss: 0.3045 - val_accuracy: 0.9237
# Epoch 15/100
# 472/472 [==============================] - 3s 6ms/step - loss: 0.1035 - accuracy: 0.9637 - val_loss: 0.2448 - val_accuracy: 0.9220
# Epoch 16/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.1012 - accuracy: 0.9654 - val_loss: 0.2728 - val_accuracy: 0.9245
# Epoch 17/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.0899 - accuracy: 0.9675 - val_loss: 0.2739 - val_accuracy: 0.9262
# Epoch 18/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.0832 - accuracy: 0.9705 - val_loss: 0.2651 - val_accuracy: 0.9262
# Epoch 19/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.0730 - accuracy: 0.9728 - val_loss: 0.2970 - val_accuracy: 0.9228
# Epoch 20/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.0701 - accuracy: 0.9767 - val_loss: 0.2522 - val_accuracy: 0.9262
# Epoch 21/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.0604 - accuracy: 0.9762 - val_loss: 0.3685 - val_accuracy: 0.9211
# Epoch 22/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.0576 - accuracy: 0.9771 - val_loss: 0.4664 - val_accuracy: 0.9211
# Epoch 23/100
# 472/472 [==============================] - 3s 5ms/step - loss: 0.0597 - accuracy: 0.9813 - val_loss: 0.3202 - val_accuracy: 0.9372
# Epoch 24/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.0587 - accuracy: 0.9803 - val_loss: 0.2936 - val_accuracy: 0.9347
# Epoch 25/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.0564 - accuracy: 0.9790 - val_loss: 0.4393 - val_accuracy: 0.9245
# Epoch 26/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.0496 - accuracy: 0.9820 - val_loss: 0.3858 - val_accuracy: 0.9338
# Epoch 27/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.0478 - accuracy: 0.9843 - val_loss: 0.2959 - val_accuracy: 0.9355
# Epoch 28/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.0463 - accuracy: 0.9849 - val_loss: 0.3352 - val_accuracy: 0.9364
# Epoch 29/100
# 472/472 [==============================] - 2s 5ms/step - loss: 0.0437 - accuracy: 0.9843 - val_loss: 0.4816 - val_accuracy: 0.9288
# Epoch 30/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.0557 - accuracy: 0.9815 - val_loss: 0.3658 - val_accuracy: 0.9262
# Epoch 31/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.0459 - accuracy: 0.9860 - val_loss: 0.6548 - val_accuracy: 0.9262
# Epoch 32/100
# 472/472 [==============================] - 2s 4ms/step - loss: 0.0563 - accuracy: 0.9834 - val_loss: 0.4878 - val_accuracy: 0.9423

# %%
final_models["7_layers_lumbar"] = model_7l

# %%
for name, model in final_models.items():
    print(f"{name}: ", end="")
    describe_model(model)
    print()
# Out:
# 3_layers_lumbar: Describe models architecture
# Layer-1: 52 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-2: 320 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-3: 2 units, func:  <function softmax at 0x000001C3932F0F70>
#
# 5_layers_lumbar: Describe models architecture
# Layer-1: 52 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-2: 256 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-3: 512 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-4: 32 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-5: 2 units, func:  <function softmax at 0x000001C3932F0F70>
#
# 7_layers_with_dropout_lumbar: Describe models architecture
# Layer-1: 52 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-2: 448 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-3: 0 units, func: None
# Layer-4: 352 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-5: 0 units, func: None
# Layer-6: 480 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-7: 2 units, func:  <function softmax at 0x000001C3932F0F70>
#
# 7_layers_lumbar: Describe models architecture
# Layer-1: 52 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-2: 64 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-3: 352 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-4: 352 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-5: 128 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-6: 384 units, func:  <function relu at 0x000001C3932F79D0>
# Layer-7: 2 units, func:  <function softmax at 0x000001C3932F0F70>

# %%
train_set_results = []

for name, model in final_models.items():
    # Evaluate model
    predict_x = model.predict(x_test, verbose=False) 
    y_pred_class = np.argmax(predict_x, axis=1)
    y_test_class = np.argmax(y_test, axis=1)

    cm = confusion_matrix(y_test_class, y_pred_class, labels=[0, 1])
    (p_score, r_score, f_score, _) = precision_recall_fscore_support(y_test_class, y_pred_class, labels=[0, 1])
    
    train_set_results.append(( name, round_up_metric_results(p_score), round_up_metric_results(r_score), round_up_metric_results(f_score), cm ))

train_set_results.sort(key=lambda k: sum(k[3]), reverse=True)
pd.DataFrame(train_set_results, columns=["Model", "Precision Score", "Recall Score", "F1 score", "Confusion Matrix"])
# Out:
#                           Model Precision Score    Recall Score  \
# 0  7_layers_with_dropout_lumbar  [0.959, 0.856]  [0.977, 0.765]
# 1               7_layers_lumbar   [0.96, 0.836]  [0.973, 0.771]
# 2               5_layers_lumbar   [0.95, 0.826]  [0.973, 0.715]
# 3               3_layers_lumbar  [0.954, 0.786]  [0.964, 0.737]
#
#          F1 score        Confusion Matrix
# 0  [0.968, 0.808]  [[977, 23], [42, 137]]
# 1  [0.966, 0.802]  [[973, 27], [41, 138]]
# 2  [0.961, 0.766]  [[973, 27], [51, 128]]
# 3  [0.959, 0.761]  [[964, 36], [47, 132]]

# %%
# load dataset
test_df = describe_dataset("./lumbar_test.csv")

# Categorizing label
test_df.loc[test_df["label"] == "lumbar_correct", "label"] = 0
test_df.loc[test_df["label"] == "lumbar_error", "label"] = 1
# Out:
# Headers: ['label', 'nose_x', 'nose_y', 'nose_z', 'nose_v', 'left_shoulder_x', 'left_shoulder_y', 'left_shoulder_z', 'left_shoulder_v', 'right_shoulder_x', 'right_shoulder_y', 'right_shoulder_z', 'right_shoulder_v', 'left_elbow_x', 'left_elbow_y', 'left_elbow_z', 'left_elbow_v', 'right_elbow_x', 'right_elbow_y', 'right_elbow_z', 'right_elbow_v', 'left_wrist_x', 'left_wrist_y', 'left_wrist_z', 'left_wrist_v', 'right_wrist_x', 'right_wrist_y', 'right_wrist_z', 'right_wrist_v', 'left_hip_x', 'left_hip_y', 'left_hip_z', 'left_hip_v', 'right_hip_x', 'right_hip_y', 'right_hip_z', 'right_hip_v', 'left_knee_x', 'left_knee_y', 'left_knee_z', 'left_knee_v', 'right_knee_x', 'right_knee_y', 'right_knee_z', 'right_knee_v', 'left_ankle_x', 'left_ankle_y', 'left_ankle_z', 'left_ankle_v', 'right_ankle_x', 'right_ankle_y', 'right_ankle_z', 'right_ankle_v']
# Number of rows: 1980
# Number of columns: 53
#
# Labels:
# lumbar_correct    1660
# lumbar_error       320
# Name: label, dtype: int64
#
# Missing values: False
#
# Duplicate Rows : 0

# %%
# Standard Scaling of features
test_x = test_df.drop("label", axis = 1)
test_x = pd.DataFrame(sc.transform(test_x))

test_y = test_df["label"]

# # Converting prediction to categorical
test_y_cat = to_categorical(test_y)

# %%
test_set_results = []

for name, model in final_models.items():
    # Evaluate model
    predict_x = model.predict(test_x, verbose=False) 
    y_pred_class = np.argmax(predict_x, axis=1)
    y_test_class = np.argmax(test_y_cat, axis=1)

    cm = confusion_matrix(y_test_class, y_pred_class, labels=[0, 1])
    (p_score, r_score, f_score, _) = precision_recall_fscore_support(y_test_class, y_pred_class, labels=[0, 1])
    
    test_set_results.append(( name, round_up_metric_results(p_score), round_up_metric_results(r_score), round_up_metric_results(f_score), cm ))

test_set_results.sort(key=lambda k: k[1] + k[2] + k[3], reverse=True)
pd.DataFrame(test_set_results, columns=["Model", "Precision Score", "Recall Score", "F1 score", "Confusion Matrix"])
# Out:
#                           Model Precision Score    Recall Score  \
# 0  7_layers_with_dropout_lumbar  [0.924, 0.659]   [0.94, 0.597]
# 1               7_layers_lumbar  [0.922, 0.613]  [0.928, 0.594]
# 2               3_layers_lumbar  [0.918, 0.577]  [0.919, 0.575]
# 3               5_layers_lumbar  [0.913, 0.646]  [0.944, 0.531]
#
#          F1 score           Confusion Matrix
# 0  [0.932, 0.626]   [[1561, 99], [129, 191]]
# 1  [0.925, 0.603]  [[1540, 120], [130, 190]]
# 2  [0.918, 0.576]  [[1525, 135], [136, 184]]
# 3  [0.928, 0.583]   [[1567, 93], [150, 170]]

# %%
final_models["7_layers_with_dropout_lumbar"].save("./model/barbell_dp.h5")

# %%
for model_name, model in final_models.items():
    model.save(f"./model/{model_name}.h5")
